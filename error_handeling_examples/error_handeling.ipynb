# %% [markdown]
# # Overview

# %%
integer = 0
string = ""
string = input("input a number as a string")
try:
    integer = int(string)
    print("success!")
except:
    print("DATA TYPE Mismatch or Illegal operation") # can just print out msg and try again or raise error with custom message to end prog.
    raise (TypeError("Fix it")) #observe the final line of the cmd output
# Out:
# DATA TYPE Mismatch or Illegal operation
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 5
#       4 try:
# ----> 5     integer = int(string)
#       6     print("success!")
#
# ValueError: invalid literal for int() with base 10: 't'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 9
#       7 except:
#       8     print("DATA TYPE Mismatch or Illegal operation") # can just print out msg and try again or raise error with custom message to end prog.
# ----> 9     raise (TypeError("Fix it"))
#
# TypeError: Fix it
